# %% [markdown]
# Imbalanced Dataset:
# A dataset with an unequal class distribution:

# %%
#importing the dependencies
import numpy as np
import pandas as pd
#loading the dataset to pandas dataFrame
credit_card_data=pd.read_csv('/content/credit_data.csv')
#First 5 rows of the data Frame
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
 credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 182324  125352.0  1.692781 -0.201306 -2.519907  1.461904  0.701510 -1.542165
# 182325  125352.0 -0.507947 -0.546918  2.291673 -2.112876 -0.845382 -0.425270
# 182326  125353.0 -1.841495 -1.506387  0.115844  0.057029 -0.202438 -0.100570
# 182327  125353.0 -2.134618  0.341463  1.033744 -0.368409  0.547263  0.069410
# 182328  125353.0 -0.499334  0.466251  1.293522 -0.763016  0.900678  1.780179
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 182324  1.432738 -0.730228 -0.371054  ...  0.433586  0.993490 -0.425314
# 182325 -0.858402  0.256730 -0.103172  ...  0.512459  1.377962 -0.181414
# 182326  0.289007  0.592253  0.040401  ...  0.715507  1.007318  0.636655
# 182327  0.439602 -0.292193  2.044366  ... -0.289225  0.605464 -0.323988
# 182328  0.134590  0.391000       NaN  ...       NaN       NaN       NaN
#
# ...

# %%
#distibution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    181963
# 1.0       365
# Name: count, dtype: int64

# %% [markdown]
# This is a highly imbalanced data set

# %%
#Separating the legit and fraudulent transactions

# %%
legit= credit_card_data[credit_card_data['Class']==0]
fraud= credit_card_data[credit_card_data['Class']==1]
print(legit.shape)
print(fraud.shape)
# Out:
# (181963, 31)
# (365, 31)

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample datset containing similar distribution of legit and fraud transaction

# %%
legit_sample=legit.sample(n=365)

# %%
legit_sample.shape
# Out:
# (365, 31)

# %% [markdown]
# Concatanate the two Data Frames

# %%
new_dataset= pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.shape
# Out:
# (730, 31)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33766    37378.0 -2.414911 -2.626376  1.053396 -0.496263 -2.474264  1.049298
# 103506   68689.0 -0.407209  1.277068  2.020340  1.945924  0.002940 -0.609505
# 172366  121071.0  1.334529 -2.761067 -2.185597 -1.295470 -1.134902 -0.745583
# 167431  118680.0 -0.873838  0.474974 -1.415775 -0.484232  1.016395 -0.760008
# 1162       908.0  1.161789 -0.317883  0.742030  0.432754 -0.292688  1.154225
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 33766   2.590614 -0.034632  0.399305  ...  0.803692  0.810694  1.712478
# 103506  0.770343 -0.008041 -1.259108  ... -0.152028 -0.599892  0.039558
# 172366  0.108792 -0.498421 -1.829326  ...  0.000476 -0.803418 -0.142131
# 167431  1.889260  0.044478 -1.530959  ...  0.537073  1.012363 -0.061086
# 1162   -0.820857  0.431601  0.751147  ... -0.084522 -0.063924 -0.102929
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 172787  121238.0 -2.628922  2.275636 -3.745369  1.226948 -1.132966 -1.256353
# 176049  122608.0 -2.003460 -7.159042 -4.050976  1.309580 -2.058102 -0.098621
# 177195  123078.0 -1.073820  0.415616 -2.273977  1.536844 -0.758697 -1.670381
# 178208  123525.0 -5.904921  4.439911 -8.631802  7.788684 -4.989580 -1.200144
# 181966  125200.0 -0.769172  1.342212 -2.171454 -0.151513 -0.648374 -0.973504
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 172787 -1.752420  0.281736 -1.792343  ...  0.870730  1.269473 -0.265494
# 176049  2.880083 -0.727484  1.460381  ...  1.244287 -1.015232 -1.800985
# 177195 -2.377140  0.090370  0.004847  ...  0.535542  0.863592  0.450743
# 178208 -7.674060  4.125761 -5.315778  ...  1.775030  1.266441 -0.199410
# 181966 -1.706658  0.313745 -1.982302  ... -0.036122 -0.753591 -0.047113
#
# ...

# %%
new_dataset.Class.value_counts()
# Out:
# Class
# 0.0    365
# 1.0    365
# Name: count, dtype: int64
